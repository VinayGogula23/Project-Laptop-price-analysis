# %% [markdown]
# # 14 SEP 2022

# %%
import requests
from bs4 import BeautifulSoup
page = requests.get('https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_na&as-pos=2&as-type=HISTORY&suggestionId=laptop%7CLaptops&requestId=995dd11e-16dc-4b09-b635-c1685cf011ad&page=16')
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57"
# ...

# %%
soup=BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Price

# %%
soup.find_all('div',class_="_30jeq3 _1_WHN1")
# Out:
# [<div class="_30jeq3 _1_WHN1">₹53,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹81,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹73,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,14,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,02,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹69,790</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,42,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹47,890</div>,
#  <div class="_30jeq3 _1_WHN1">₹47,395</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,20,000</div>,
#  <div class="_30jeq3 _1_WHN1">₹53,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,49,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,960</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,057</div>,
#  <div class="_30jeq3 _1_WHN1">₹47,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹48,990</div>,
# ...

# %%
len(soup.find_all('div',class_="_30jeq3 _1_WHN1"))
# Out:
# 24

# %%
p=soup.find_all('div',class_="_30jeq3 _1_WHN1")
p[0]
# Out:
# <div class="_30jeq3 _1_WHN1">₹53,990</div>

# %%
p[0].text
# Out:
# '₹53,990'

# %%
prices=[]
for i in p:
    prices.append(i.text)
prices
# Out:
# ['₹53,990',
#  '₹34,999',
#  '₹29,999',
#  '₹81,990',
#  '₹73,490',
#  '₹1,14,990',
#  '₹1,02,990',
#  '₹69,790',
#  '₹41,990',
#  '₹1,42,990',
#  '₹47,890',
#  '₹47,395',
#  '₹1,20,000',
#  '₹53,490',
#  '₹26,990',
#  '₹1,49,990',
#  '₹38,940',
#  '₹29,960',
#  '₹36,057',
#  '₹47,990',
#  '₹48,990',
#  '₹2,27,990',
#  '₹86,990',
#  '₹52,199']

# %%
len(prices)
# Out:
# 24

# %% [markdown]
# # Brand

# %%
soup.find_all('div',class_='_4rR01T')
# Out:
# [<div class="_4rR01T">DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...</div>,
#  <div class="_4rR01T">HP Notebook PC Core i3 11th Gen - (8 GB/1 TB HDD/Windows 10) G8 240 Thin and Light Laptop</div>,
#  <div class="_4rR01T">HP Pentium Quad Core - (8 GB/256 GB SSD/Windows 11 Home) 14s-dq3033tu Thin and Light Laptop</div>,
#  <div class="_4rR01T">Lenovo Thinkbook Convertible Core i7 11th Gen - (16 GB/512 GB SSD/Windows 10 Home) TB14s ITL Yoga 2 in...</div>,
#  <div class="_4rR01T">APPLE MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A</div>,
#  <div class="_4rR01T">acer Predator Helios 300 Core i9 11th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeFor...</div>,
#  <div class="_4rR01T">Lenovo Yoga Slim 7 Intel EVO Core i7 11th Gen - (16 GB/1 TB SSD/Windows 10 Home) Yoga Slim 7 14ITL05b ...</div>,
# ...

# %%
b=soup.find_all('div',class_='_4rR01T')
b[0]
# Out:
# <div class="_4rR01T">DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...</div>

# %%
b[0].text
# Out:
# 'DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...'

# %%
b[0].text.split()[0]
# Out:
# 'DELL'

# %%
brand=[]
for i in b:
    brand.append(i.text.split()[0])
brand
# Out:
# ['DELL',
#  'HP',
#  'HP',
#  'Lenovo',
#  'APPLE',
#  'acer',
#  'Lenovo',
#  'DELL',
#  'ASUS',
#  'ASUS',
#  'HP',
#  'DELL',
#  'HP',
#  'Lenovo',
#  'HP',
#  'MSI',
#  'DELL',
#  'ASUS',
#  'DELL',
#  'ASUS',
#  'ASUS',
#  'APPLE',
#  'LG',
#  'acer']

# %%
len(brand)
# Out:
# 24

# %% [markdown]
# # RAM

# %%
b[0]
# Out:
# <div class="_4rR01T">DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...</div>

# %%
import re
re.findall(r'\d+\sGB',b[0].text)[0].split()[0]
# Out:
# '4'

# %%
b
# Out:
# [<div class="_4rR01T">DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...</div>,
#  <div class="_4rR01T">HP Notebook PC Core i3 11th Gen - (8 GB/1 TB HDD/Windows 10) G8 240 Thin and Light Laptop</div>,
#  <div class="_4rR01T">HP Pentium Quad Core - (8 GB/256 GB SSD/Windows 11 Home) 14s-dq3033tu Thin and Light Laptop</div>,
#  <div class="_4rR01T">Lenovo Thinkbook Convertible Core i7 11th Gen - (16 GB/512 GB SSD/Windows 10 Home) TB14s ITL Yoga 2 in...</div>,
#  <div class="_4rR01T">APPLE MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A</div>,
#  <div class="_4rR01T">acer Predator Helios 300 Core i9 11th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeFor...</div>,
#  <div class="_4rR01T">Lenovo Yoga Slim 7 Intel EVO Core i7 11th Gen - (16 GB/1 TB SSD/Windows 10 Home) Yoga Slim 7 14ITL05b ...</div>,
# ...

# %%
RAM=[]
for i in b:
    RAM.append(re.findall(r'\d+\sGB',i.text)[0].split()[0])
RAM
# Out:
# ['4',
#  '8',
#  '8',
#  '16',
#  '8',
#  '16',
#  '16',
#  '8',
#  '8',
#  '32',
#  '8',
#  '8',
#  '16',
#  '8',
#  '4',
#  '16',
#  '8',
#  '4',
#  '4',
#  '8',
#  '8',
#  '16',
#  '8',
#  '8']

# %%
len(RAM)
# Out:
# 24

# %% [markdown]
# # SSD

# %%
b[0]
# Out:
# <div class="_4rR01T">DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...</div>

# %%
re.findall(r'\d+\sGB\sSSD',b[0].text)[0].split()[0]
# Out:
# '256'

# %%
import numpy as np

# %%
b[0].text
# Out:
# 'DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...'

# %%
for i in b:
    print(i.text)
# Out:
# DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...
# HP Notebook PC Core i3 11th Gen - (8 GB/1 TB HDD/Windows 10) G8 240 Thin and Light Laptop
# HP Pentium Quad Core - (8 GB/256 GB SSD/Windows 11 Home) 14s-dq3033tu Thin and Light Laptop
# Lenovo Thinkbook Convertible Core i7 11th Gen - (16 GB/512 GB SSD/Windows 10 Home) TB14s ITL Yoga 2 in...
# APPLE MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A
# acer Predator Helios 300 Core i9 11th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeFor...
# Lenovo Yoga Slim 7 Intel EVO Core i7 11th Gen - (16 GB/1 TB SSD/Windows 10 Home) Yoga Slim 7 14ITL05b ...
# DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX 3050) G15-55...
# ASUS VivoBook K15 OLED (2022) Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) K513EA-L302TS Thin ...
# ...

# %%
#128 GB EMMC Storage

# %%
SSD=[]
for i in b:
    
    a=(re.findall(r'\d+\sGB\sSSD|\d+\sTB\sHDD|\d+\sTB\sSSD|\d+\sGB\sEMMC',i.text)[0].split())
    SSD.append(a)
SSD
# Out:
# [['1', 'TB', 'HDD'],
#  ['1', 'TB', 'HDD'],
#  ['256', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['128', 'GB', 'SSD'],
#  ['1', 'TB', 'SSD'],
#  ['1', 'TB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['256', 'GB', 'SSD'],
#  ['1', 'TB', 'SSD'],
#  ['256', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['1', 'TB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['64', 'GB', 'EMMC'],
#  ['1', 'TB', 'SSD'],
#  ['256', 'GB', 'SSD'],
#  ['128', 'GB', 'SSD'],
#  ['256', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD'],
#  ['512', 'GB', 'SSD']]

# %%
len(SSD)
# Out:
# 24

# %%
b[0].text
# Out:
# 'DELL Inspiron Core i5 11th Gen - (4 GB/1 TB HDD/256 GB SSD/Windows 10) Inspiron 3501 Thin and Light La...'

# %% [markdown]
# # Windows

# %%
#Mac OS

# %%
re.findall(r'Windows\s\d+|Mac OS|DOS',b[6].text)
# Out:
# ['Windows 10']

# %%
Windows=[]
for i in b:
    
    a=re.findall(r'Windows\s\d+|Mac OS|DOS|\d+\sGB\sEMMC',i.text)
    #print(a)
    if len(a)>0: 
        Windows.append(a[0])
    else:
        Windows.append(np.nan)
Windows
# Out:
# ['Windows 10',
#  'Windows 10',
#  'Windows 11',
#  'Windows 10',
#  'Mac OS',
#  'Windows 11',
#  'Windows 10',
#  'Windows 11',
#  'Windows 10',
#  'Windows 10',
#  'Windows 10',
#  'Windows 10',
#  'Windows 10',
#  'Windows 11',
#  '64 GB EMMC',
#  'Windows 11',
#  'Windows 11',
#  'Windows 11',
#  'Windows 10',
#  'Windows 11',
#  'Windows 11',
#  'Mac OS',
#  'Windows 11',
#  'Windows 11']

# %%
len(Windows )
# Out:
# 24

# %%
spacifications=soup.find_all('ul',class_='_1xgFaf')

# %%
spacifications[0].text
# Out:
# 'Intel Core i5 Processor (11th Gen)4 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD|256 GB SSD37.85 cm (14.9 Inch) DisplayMicrosoft Office Home and Student 20191 Year Onsite Warranty'

# %% [markdown]
# # BIT

# %%
re.findall(r'\d+\sbit',spacifications[0].text)
# Out:
# ['64 bit']

# %%
bit=[]
for i in spacifications:
    a=re.findall(r'(\d+)\sbit',i.text)
    if len(a)>0:
        bit.append(a[0])
    else:
        bit.append(np.nan)
bit
# Out:
# ['64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  nan,
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  '64',
#  nan,
#  nan,
#  nan,
#  '64',
#  '64']

# %%
len(bit)
# Out:
# 24

# %% [markdown]
# # Sreen size

# %%
spacifications[0].text
# Out:
# 'Intel Core i5 Processor (11th Gen)4 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD|256 GB SSD37.85 cm (14.9 Inch) DisplayMicrosoft Office Home and Student 20191 Year Onsite Warranty'

# %%
re.findall(r'\d+\sinch',spacifications[0].text)
# Out:
# []

# %%
Screen_Size=[]
for i in spacifications:
    a=(re.findall(r'(\d+)\sinch',i.text))
    if a:
        Screen_Size.append(a[0])
    else:
        Screen_Size.append(np.nan)
Screen_Size
# Out:
# [nan,
#  '14',
#  '14',
#  '14',
#  '3',
#  nan,
#  '14',
#  '6',
#  '6',
#  '4',
#  '14',
#  '14',
#  '6',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '14',
#  '14',
#  '14',
#  '2',
#  '16',
#  '6']

# %%
len(Screen_Size)
# Out:
# 24

# %%
spacifications[0].text
# Out:
# 'Intel Core i5 Processor (11th Gen)4 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD|256 GB SSD37.85 cm (14.9 Inch) DisplayMicrosoft Office Home and Student 20191 Year Onsite Warranty'

# %% [markdown]
# # Warranty

# %%
re.findall(r'(\d)\s\w+\s\w+\sWarranty',spacifications[0].text)
# Out:
# ['1']

# %%
Warranty=[]
for i in spacifications:
    a=re.findall(r'(\d)\s\w+\s\w+\sWarranty',i.text)
    if a:
        Warranty.append(a[0])
    else:
        Warranty.append(np.nan)
Warranty
# Out:
# ['1',
#  '1',
#  '1',
#  '3',
#  nan,
#  nan,
#  nan,
#  nan,
#  '1',
#  '1',
#  '1',
#  '1',
#  nan,
#  '1',
#  '1',
#  nan,
#  '1',
#  '1',
#  nan,
#  '1',
#  '1',
#  '1',
#  '3',
#  nan]

# %%
len(Warranty)
# Out:
# 24

# %% [markdown]
# # PROCESSOR

# %%
b[23]
# Out:
# <div class="_4rR01T">HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop</div>

# %%
import re
import numpy as np

# %%
re.findall(r'Core\si\d|Ryzen\s\d',b[23].text)[0]
# Out:
# 'Core i5'

# %%
processor=[]
for i in b:
    a=re.findall(r'Core\si\d|Ryzen\s\d',i.text)
    if a:
        processor.append(a[0])
    else: 
        processor.append(np.nan)
processor
# Out:
# ['Ryzen 5',
#  'Core i5',
#  'Core i3',
#  'Ryzen 5',
#  'Ryzen 5',
#  'Ryzen 5',
#  'Core i3',
#  'Ryzen 7',
#  'Core i3',
#  'Core i3',
#  nan,
#  'Ryzen 7',
#  'Ryzen 7',
#  'Core i5',
#  'Core i5',
#  'Core i3',
#  nan,
#  nan,
#  'Core i5',
#  'Core i3',
#  'Core i3',
#  'Core i3',
#  'Core i3',
#  'Core i5']

# %%
len(processer)
# Out:
# 24

# %% [markdown]
# # GEN- generation

# %%
import re

# %%
gen=soup.find_all('div',class_=('_3pLy-c row'))
gen[0].text
# Out:
# 'LG Gram Core i5 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) Gram 14Z90P-G.AJ61A2 Thin and Light Lapto...4.73 Ratings\xa0&\xa01 ReviewsIntel Core i5 Processor (11th Gen)8 GB DDR4 RAM64 bit Windows 11 Operating System256 GB SSD35.56 cm (14 inch) Display3 Year onsite Warranty ( 1st year International & last 2 year National)₹76,990₹1,06,00027% offFree deliveryUpto ₹17,750 Off on ExchangeBank Offer'

# %%
re.findall(r'\d+th\sGen|\d{4}U|\d{4}H',gen[1].text)
# Out:
# ['4600H']

# %%
import numpy as np

# %%
generation2=[]
for i in gen:
    a=(re.findall(r'\d+th\sGen|\d{4}U|\d{4}H',i.text))
    if a:
        if len(a)>0:
             generation2.append(a[0])
        else:
             generation2.append(a)
    else:generation2.append(np.nan)

# %%
generation2
# Out:
# ['11th Gen',
#  '4600H',
#  '11th Gen',
#  '11th Gen',
#  '11th Gen',
#  '11th Gen',
#  '11th Gen',
#  '5800H',
#  nan,
#  '6800H',
#  '4800H',
#  '11th Gen',
#  '6800H',
#  nan,
#  '10th Gen',
#  '5980H',
#  '10th Gen',
#  nan,
#  '5800H',
#  '5800H',
#  '11th Gen',
#  '11th Gen',
#  '3250U',
#  '11th Gen']

# %%
#rating

# %%
r=soup.find_all('div',class_=('_3LWZlK'))
r[0].text
# Out:
# '4'

# %%
rating=[]
for i in r:
    rating.append(i.text)
x=rating[0:24]
x
# Out:
# ['4',
#  '4.7',
#  '4.1',
#  '4.2',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.7',
#  '4.7',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.3',
#  '5',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.2',
#  '4',
#  '2',
#  '4.4']

# %%
rating
# Out:
# ['4',
#  '4.7',
#  '4.1',
#  '4.2',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.7',
#  '4.7',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.3',
#  '5',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.2',
#  '4',
#  '2',
#  '4.4',
#  '4',
#  '4',
#  '4.3',
#  '4',
#  '2',
#  '4.5',
#  '5',
#  '4',
#  '4.1',
#  '3',
#  '3']

# %%
len(rating)
# Out:
# 35

# %%
x
# Out:
# ['4',
#  '4.7',
#  '4.1',
#  '4.2',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.7',
#  '4.7',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.3',
#  '5',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.2',
#  '4',
#  '2',
#  '4.4']

# %%
len(x)
# Out:
# 24
